# %%
import pandas as pd
import seaborn as sb
df = pd.read_csv('StudentsPerformance.csv') 
sns.scatterplot(data = df, x="math score", y="writing score")
# Out:
# <AxesSubplot:xlabel='math score', ylabel='writing score'>

# %%
sns.scatterplot(data = df, x="writing score", y="reading score")
# Out:
# <AxesSubplot:xlabel='writing score', ylabel='reading score'>

# %%
sns.scatterplot(data = df, x="math score", y="reading score", hue="gender")
# Out:
# <AxesSubplot:xlabel='math score', ylabel='reading score'>

# %%
sns.scatterplot(data = df, x="parental level of education", y="reading score")
# Out:
# <AxesSubplot:xlabel='parental level of education', ylabel='reading score'>

# %%
sns.scatterplot(data = df, x="parental level of education", y="writing score")
# Out:
# <AxesSubplot:xlabel='parental level of education', ylabel='writing score'>

# %%
sns.scatterplot(data = df, x="lunch", y="writing score")
# Out:
# <AxesSubplot:xlabel='lunch', ylabel='writing score'>

# %%
sns.scatterplot(data = df, x="race/ethnicity", y="math score")
# Out:
# <AxesSubplot:xlabel='race/ethnicity', ylabel='math score'>
